# %% [markdown]
# <a href="https://colab.research.google.com/github/pauchai/SubPlayer/blob/master/Paul%20Himyack/profpatolog.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!wget -c "https://storage.yandexcloud.net/terratraineeship/23_InspectrumClinic_RS/datasets/%D1%81%D0%B5%D0%BC%D0%BF%D0%BB%20%D0%B4%D0%B0%D1%82%D0%B0%D1%81%D0%B5%D1%82%D0%B0.xlsx"
# !wget -qc "https://storage.yandexcloud.net/terratraineeship/23_InspectrumClinic_RS/datasets/%D0%B4%D0%B0%D1%82%D0%B0%D1%81%D0%B5%D1%82%20%D0%BF%D1%80%D0%BE%D1%84%D0%BF%D0%B0%D1%82%D0%BE%D0%BB%D0%BE%D0%B3%20%D1%87%D0%B0%D1%81%D1%82%D1%8C.xlsx"

# %%
import pandas as pd
import matplotlib.pyplot as plt
import uuid
import re
import numpy as np
import seaborn as sns

# %%
#df = pd.read_excel("семпл датасета.xlsx")
df = pd.read_excel("датасет профпатолог часть.xlsx")

# %%
#Удаляем случайные вбросы
df.drop([843, 851, 1022, 1024], inplace = True)

# %%
#Убираем пустые колонки
empty_columns = df.columns[df.isna().all()]
df.drop(empty_columns, inplace = True, axis = 1)

# %%
FIELD_CLIENT_AGE = "КлиентВозраст"
FIELD_CLIENT_BIRTH_DAY = "КлиентДатаРождения"
FIELD_CLIENT_GENDER = "КлиентПол"
FIELD_CLIENT_GENDER_M = 0
FIELD_CLIENT_GENDER_F = 1
FIELD_CONCLUSION = "ЗаключениеМК"
FIELD_CONCLUSION_FIT = 0
FIELD_CONCLUSION_PART_FIT = 1
FIELD_CONCLUSION_NOT_FIT = 2

FIELD_DISPANSARY_GROUP = "ДиспансернаяГруппа"
FIELD_DISPANSARY_GROUP_I = 0
FIELD_DISPANSARY_GROUP_II = 1
FIELD_DISPANSARY_GROUP_III = 2
FIELD_DISPANSARY_GROUP_OTHER = 3

FIELD_HARMFUL_FACTORS = "ВредныеФакторы"

# %%
from datetime import datetime
# Определяем функцию для расчета возраста на основе даты
def calculate_age_from_date(date):
    current_year = pd.Timestamp.now().year
    age = current_year - date.year
    return age

# %%
df[FIELD_CLIENT_GENDER].value_counts()
# Out:
# Мужской    1447
# Женский     531
# Name: КлиентПол, dtype: int64

# %%
# Определяем функцию для замены значений
def replace_gender(x):
    if x == 'Мужской':
        return FIELD_CLIENT_GENDER_M
    elif x == 'Женский':
        return FIELD_CLIENT_GENDER_F
    else:
        return None

# %%
df[FIELD_CONCLUSION].value_counts()
# Out:
# Годен                               1434
# ГоденСКоррекциейЗрения               123
# ВременноНегоден                        9
# НуждаетсяВДообследованииИЛечении       2
# ОграниченноГоден                       2
# ГоденБезРаботНаВысотах                 1
# Name: ЗаключениеМК, dtype: int64

# %%
def resolve_conclusion(arg):
  try:
    if "Годен" == arg:
      return FIELD_CONCLUSION_FIT
    elif "Негоден" in arg:
      return FIELD_CONCLUSION_NOT_FIT
    elif "Годен" in arg:
      return FIELD_CONCLUSION_PART_FIT
    else:
      return FIELD_CONCLUSION_NOT_FIT
  except (TypeError):
      return None

# %%
print(resolve_conclusion("ВременноНегоден"))
# Out:
# 2

# %%
df[FIELD_DISPANSARY_GROUP].value_counts()
# Out:
# I       779
# II      389
# IIIа    369
# IIIб     25
# Name: ДиспансернаяГруппа, dtype: int64

# %%
def resolve_dispansary_group(arg):
  try:
    if arg == "I":
      return FIELD_DISPANSARY_GROUP_I
    elif arg == "II":
      return FIELD_DISPANSARY_GROUP_II
    elif "III" in arg :
      return FIELD_DISPANSARY_GROUP_III
    else:
      return FIELD_DISPANSARY_GROUP_OTHER
  except (TypeError):
      return None

# %%
df1 = df[FIELD_HARMFUL_FACTORS].str.split(",")

# %%
#Значения вредных факторов. Нужно как-то токенизировать
df1.explode().sort_values().unique()
# Out:
# array(['1.1', '1.14.1', '1.14.2', '1.15', '1.17', '1.18.3', '1.19.1',
#        '1.2', '1.23', '1.24', '1.29', '1.29.1', '1.29.2', '1.29.4', '1.3',
#        '1.30.1', '1.34.1', '1.36', '1.36.1', '1.37', '1.37.1', '1.37.1.1',
#        '1.37.1.2', '1.39', '1.45.1', '1.46', '1.48', '1.49', '1.49.14',
#        '1.49.2', '1.50', '1.8.1', '1.8.1.1', '1.8.1.2', '1.8.2',
#        '1.8.2.1', '1.8.2.2', '1.8.3', '1.8.3.1', '1.8.3.2', '10', '11',
#        '11.1', '11.2', '11.3', '11.4', '12', '13', '14', '15', '17', '18',
#        '18.1', '18.2', '2.4', '2.4.3', '22', '23', '24', '25', '26', '27',
#        '3.1', '3.1.2', '3.1.7', '3.1.8.1', '3.1.8.2', '3.1.8.3', '3.4',
#        '4.1', '4.10', '4.2', '4.2.1', '4.2.3', '4.2.4', '4.2.5', '4.3.1',
#        '4.3.2', '4.4', '4.5', '4.6', '4.7', '4.8', '4.9', '5.1', '5.2',
#        '5.2.1', '6', '6.1', '6.2', '8', '9'], dtype=object)

# %%
fields = [
    "КлиентДатаРождения ", "КлиентПол", "ТипМедосмотра", 
    "ПсихОсвидетельствование", "Профессия", "ЗаключениеМК",
    "ДиспансернаяГруппа", "ВредныеФакторы"
]

# %%
df_new = pd.DataFrame()

# %%
#Поле возраста
df_new[FIELD_CLIENT_AGE] = df[FIELD_CLIENT_BIRTH_DAY].apply(calculate_age_from_date)

# %%
#Поле секс
df_new[FIELD_CLIENT_GENDER] = df[FIELD_CLIENT_GENDER].apply(lambda x: replace_gender(x) if pd.notnull(x) else x)

# %%
#Диспансерная группа 
df_new[FIELD_DISPANSARY_GROUP] = df[FIELD_DISPANSARY_GROUP].apply(resolve_dispansary_group).head()

# %%
#Вредные факторы преобразовать в массив
df_new[FIELD_HARMFUL_FACTORS] = df[FIELD_HARMFUL_FACTORS].str.split(",")

# %%
df[FIELD_CONCLUSION].info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 1978 entries, 0 to 1981
# Series name: ЗаключениеМК
# Non-Null Count  Dtype
# --------------  -----
# 1571 non-null   object
# dtypes: object(1)
# memory usage: 30.9+ KB

# %%
df_new[FIELD_CONCLUSION] = df[FIELD_CONCLUSION].apply(lambda x: resolve_conclusion(x))

# %%
df_new[FIELD_CONCLUSION + "OLD"] = df[FIELD_CONCLUSION]

# %%
df_new
# Out:
#       КлиентВозраст  КлиентПол  ДиспансернаяГруппа ВредныеФакторы  \
# 0                47          1                 0.0         [11.4]
# 1                36          0                 2.0        [4.2.5]
# 2                38          0                 1.0        [4.2.5]
# 3                35          0                 0.0         [11.1]
# 4                39          0                 1.0         [11.1]
# ...             ...        ...                 ...            ...
# 1977             51          0                 NaN          [6.1]
# 1978             37          0                 NaN          [6.1]
# 1979             29          0                 NaN      [5.1, 23]
# 1980             51          1                 NaN           [23]
# 1981             52          0                 NaN           [27]
#
#       ЗаключениеМК         ЗаключениеМКOLD
# 0              0.0                   Годен
# 1              0.0                   Годен
# 2              1.0  ГоденСКоррекциейЗрения
# 3              0.0                   Годен
# 4              1.0  ГоденСКоррекциейЗрения
# ...            ...                     ...
# 1977           NaN                     NaN
# 1978           NaN                     NaN
# 1979           NaN                     NaN
# 1980           NaN                     NaN
# 1981           0.0                   Годен
#
# [1978 rows x 6 columns]

# %%
# Задаем размер полотна
plt.figure(figsize=(10,8))

# Добавляем название графика
plt.title('Проверка сбалансированности данных', fontsize=16)

# Строим график countplot
sns.countplot(x=FIELD_CONCLUSION, data=df_new)
# Out:
# <Axes: title={'center': 'Проверка сбалансированности данных'}, xlabel='ЗаключениеМК', ylabel='count'>

# %%
# Задаем параметры полотна
fig, ax = plt.subplots(2,3, sharex=False, sharey=False,figsize=(15,10), constrained_layout=True)

# Добавляем название графика
fig.suptitle('Частотный анализ данных', fontsize=25)

# Отрисовываем графики по каждому параметру
sns.countplot(x= FIELD_DISPANSARY_GROUP, data=df_new, ax=ax[0,0])
sns.countplot(x= FIELD_CLIENT_GENDER, data=df_new, ax=ax[0,1])
sns.countplot(x= FIELD_CLIENT_AGE, data=df_new, ax = ax[0,2])
# Out:
# <Axes: xlabel='КлиентВозраст', ylabel='count'>

# %%
# Задаем параметры полотна
fig, ax = plt.subplots(1,2, sharex=False, sharey=False,figsize=(15,10), constrained_layout=True)

# Добавляем название графика
fig.suptitle('Частотный анализ данных относительно целевой переменной', fontsize=25)

# Отрисовываем графики по каждому параметру
sns.countplot(x= FIELD_CLIENT_GENDER, hue= FIELD_CONCLUSION,data=df_new, ax=ax[0])
sns.countplot(x= FIELD_DISPANSARY_GROUP, hue= FIELD_CONCLUSION ,data=df_new, ax = ax[1])
# Out:
# <Axes: xlabel='ДиспансернаяГруппа', ylabel='count'>

# %%
# Задаем размер полотна
plt.figure(figsize=(40,10))

# Добавляем название графика
plt.title('Частотный анализ Age относительно целевой переменной', fontsize=16)

# Строим график countplot
sns.countplot(x= FIELD_CLIENT_AGE, hue= FIELD_CONCLUSION, data=df_new)
# Out:
# <Axes: title={'center': 'Частотный анализ Age относительно целевой переменной'}, xlabel='КлиентВозраст', ylabel='count'>

# %%
# список колонок с международной классификацией болезней. Скорее всего их колличество равно всем специализациям на профосмотре
mkb_columns = df.filter(regex="(?i)МКБ10").columns
print(mkb_columns)
# Out:
# Index(['ПсихиатрияНаркология1_МКБ101', 'Офтальмология1_МКБ101',
#        'Оториноларингология1_МКБ101', 'ХирургНеИсп1_МКБ101',
#        'Гинекология1_МКБ101', 'Стоматология1_МКБ101',
#        'Дерматовенерология1_МКБ101', 'Рентгенология1_МКБ101',
#        'Неврология1_МКБ101', 'Терапия1_МКБ101', 'Хирургия1_МКБ101',
#        'Офтальмология1_МКБ102', 'Терапия2_МКБ101', 'Неврология2_МКБ101',
#        'ЛабораторныеИсследования1_МКБ101', 'ЭКГНеИсп1_МКБ101',
#        'УЗИДиагностика1_МКБ101', 'УЗИДиагностика2_МКБ101',
#        'ПсихиатрияНаркология2_МКБ101', 'Терапия1_МКБ102',
#        'ЛабораторныеИсследования2_МКБ101', 'Терапия1_МКБ103',
#        'Психиатрия1_МКБ101', 'Гинекология1_МКБ102', 'Рентгенология2_МКБ101',
#        'Гинекология2_МКБ101', 'Хирургия2_МКБ101',
#        'ПроцедурнаяМедсестра1_МКБ101', 'ФункциональнаяДиагностика1_МКБ101',
#        'УЗИДиагностика1_МКБ102', 'Стоматология2_МКБ101', 'Неврология1_МКБ102',
#        'Оториноларингология2_МКБ101', 'Дерматовенерология1_МКБ102',
#        'Дерматовенерология2_МКБ101', 'Дерматовенерология2_МКБ102',
#        'Хирургия1_МКБ102', 'Хирургия2_МКБ102', 'Офтальмология2_МКБ101',
#        'Офтальмология2_МКБ102', 'Неврология2_МКБ102',
#        'ПсихиатрияНаркология1_МКБ102', 'ПсихиатрияНаркология2_МКБ102',
#        'УЗИДиагностика2_МКБ102', 'Оториноларингология1_МКБ102',
#        'Оториноларингология2_МКБ102', 'Терапия2_МКБ102',
#        'Оториноларингология1_МКБ103', 'Оториноларингология1_МКБ104',
#        'Оториноларингология2_МКБ103', 'Оториноларингология2_МКБ104',
#        'Терапия3_МКБ101', 'Терапия3_МКБ102', 'Терапия4_МКБ101',
#        'Терапия4_МКБ102', 'Гинекология2_МКБ102', 'УЗИДиагностика1_МКБ103',
#        'УЗИДиагностика1_МКБ104', 'УЗИДиагностика2_МКБ103',
#        'УЗИДиагностика2_МКБ104', 'Стоматология1_МКБ102',
#        'Стоматология2_МКБ102', 'Терапия1_МКБ104', 'Терапия2_МКБ103',
#        'Терапия2_МКБ104', 'Офтальмология1_МКБ103', 'Офтальмология1_МКБ104',
#        'Офтальмология2_МКБ103', 'Офтальмология2_МКБ104',
#        'ЛабораторныеИсследования1_МКБ102', 'ЛабораторныеИсследования2_МКБ102',
#        'Хирургия3_МКБ101', 'Гинекология3_МКБ101', 'Гинекология3_МКБ102',
#        'Гинекология4_МКБ101', 'Гинекология4_МКБ102', 'ТерапевтНеИсп1_МКБ101',
#        'Эндоскопия1_МКБ101', 'ТерапевтНеИсп1_МКБ102', 'ХирургНеИсп1_МКБ102',
#        'ХирургНеИсп2_МКБ101', 'ХирургНеИсп2_МКБ102', 'Психиатрия1_МКБ102',
#        'Психиатрия2_МКБ101', 'Психиатрия2_МКБ102', 'Рентгенология1_МКБ102',
#        'Рентгенология2_МКБ102', 'Психиатрия3_МКБ101', 'Психиатрия3_МКБ102',
#        'Психиатрия4_МКБ101', 'Психиатрия4_МКБ102',
#        'Оториноларингология3_МКБ101'],
#       dtype='object')

# %%
import hashlib
def calculate_md5(value):
    # Преобразуем строку UUID в байтовый формат
    value_bytes = value.encode('utf-8')
    # Создаем объект хеш-функции MD5
    md5 = hashlib.md5()
    # Обновляем хеш-функцию байтами UUID
    md5.update(value_bytes)
    # Получаем хеш-код MD5 в шестнадцатеричном формате
    md5_hash = md5.hexdigest()
    integer_hash = int(md5_hash, 16)
    return integer_hash

# %%
# Функция для преобразования UUID в int
def uuid_to_int(x):
    try:
        return int(uuid.UUID(x))
    except (ValueError, AttributeError):
        return 1

# %%
def resolve_columns_where_uuid_and_simple_text(df):
  columns = []
  # Паттерн для проверки UUID-идентификаторов
  uuid_pattern = r'^[a-f\d]{8}(-[a-f\d]{4}){3}-[a-f\d]{12}$'

  # Перебор всех колонок в DataFrame
  for column_name in df.columns:
      # Проверка наличия текстовых значений в колонке
      has_text = df[column_name].dropna().apply(lambda x: bool(re.match(uuid_pattern, str(x))))
      
      # Вывод информации о колонке, если есть текстовые значения помимо UUID-идентификаторов
      if has_text.any():
        if has_text.all():
          continue
        columns.append(column_name)
        #print(f"Колонка '{column_name}' содержит текстовые значения помимо UUID-идентификаторов.")
  return columns

# %%
mixed_columns_with_UUID = resolve_columns_where_uuid_and_simple_text(df)
print("колонки в которых перемежаются типы данных uuid и просто текст", ":",len(mixed_columns_with_UUID) )
print(mixed_columns_with_UUID)
# Out:
# колонки в которых перемежаются типы данных uuid и просто текст : 27
# ['ПсихиатрияНаркология1_БезСледовВВИнъекций_Значение', 'ПсихиатрияНаркология1_Внимание_Значение', 'ПсихиатрияНаркология1_МышлениеВ_Значение', 'ПсихиатрияНаркология1_Эмоционально_Значение', 'ПсихиатрияНаркология1_Интеллект_Значение', 'Офтальмология1_OD_Значение', 'Офтальмология1_OS_Значение', 'Гинекология1_МолочныеЖелезы_Значение', 'Стоматология1_Прикус_Значение', 'Терапия1_СВысыпаниями_Значение', 'УЗИДиагностика1_Размеры_Значение', 'УЗИДиагностика1_Контуры_Значение', 'УЗИДиагностика1_СосудистыйРисунок_Значение', 'УЗИДиагностика1_Форма_Значение', 'УЗИДиагностика1_Эхогенность_Значение', 'УЗИДиагностика1_Структура_Значение', 'УЗИДиагностика1_ВирсунговПроток_Значение', 'УЗИДиагностика1_Содержимое_Значение', 'Терапия2_СВысыпаниями_Значение', 'УЗИДиагностика2_Контуры_Значение', 'УЗИДиагностика2_СосудистыйРисунок_Значение', 'УЗИДиагностика2_Форма_Значение', 'УЗИДиагностика2_Эхогенность_Значение', 'УЗИДиагностика2_Структура_Значение', 'УЗИДиагностика2_ВирсунговПроток_Значение', 'ПсихиатрияНаркология2_Внимание_Значение', 'ПсихиатрияНаркология2_Эмоционально_Значение']

# %%
# Проход по столбцам в цикле
with open('columns_sumary.txt', 'w') as fd:
  for i, (column_name, column_data) in enumerate(df.iteritems()):
      print(i, " ", column_name, ":", file=fd)
      print(df[column_name].value_counts().head().to_string(), file=fd)
      print("--------------", file=fd)

# %%
(df.columns + " | " +  df.loc[3].astype("str")).to_list()
# Out:
# ['ДокументПрохождениеМедосмотра | b8a33910-8eec-11ec-80fe-0cc47aab8067',
#  'Клиент | 98f9d761-8d65-11ec-80fe-0cc47aab8067',
#  'КлиентДатаРождения | 1988-04-25 00:00:00',
#  'КлиентПол | Мужской',
#  'КлиентПолПредставление | Мужской',
#  'ДатаЗавершенияМедосмотра | 2022-02-16 00:00:00',
#  'ТипМедосмотра | Периодический',
#  'ТипМедосмотраПредставление | Периодический',
#  'ПсихОсвидетельствование | False',
#  'Контрагент | a6d559b0-7835-11eb-80e8-0cc47aab8067',
#  'Цех | Отдел техники и технологии строительства скважин',
#  'Профессия | Главный специалист',
#  'ЗаключениеМК | Годен',
#  'ЗаключениеМКПредставление | Годен к работе в указанных условиях',
#  'Заключение | Годен к работе в указанных условиях',
#  'ДиспансернаяГруппа | I',
#  'ДиспансернаяГруппаПредставление | I',
#  'ВредныеФакторы | 11.1',
#  'ЛабораторныеИсследования1_ДокументПрием | a1fb1fc6-8efb-11ec-80fe-0cc47aab8067',
#  'ЛабораторныеИсследования1_ДатаПриема | 2022-02-16 12:40:02',
#  'ЛабораторныеИсследования1_Салон | 1b071e3e-c87a-11e7-80de-708bcd7f83cd',
#  'ЛабораторныеИсследования1_СалонПредставление | МЦ№2',
#  'ЛабораторныеИсследования1_Специализация | e866ea50-093d-11e2-87b2-002618dcef2c',
#  'ЛабораторныеИсследования1_СпециализацияПредставление | Лабораторные исследования',
#  'ЛабораторныеИсследования1_ХР_Рекомендация1 | nan',
#  'ЛабораторныеИсследования1_ХР_Рекомендация1Представление | nan',
#  'ЛабораторныеИсследования1_ХР_Рекомендация2 | nan',
#  'ЛабораторныеИсследования1_ОАК_Значение | получен',
#  'ЛабораторныеИсследования1_ОАК_ЗначениеПредставление | получен',
#  'ЛабораторныеИсследования1_Биохимия_Значение | получен',
#  'ЛабораторныеИсследования1_Биохимия_ЗначениеПредставление | получен',
#  'ЛабораторныеИсследования1_ОАМ_Значение | получен',
#  'ЛабораторныеИсследования1_ОАМ_ЗначениеПредставление | получен',
#  'ЛабораторныеИсследования1_МазокИзЗеваИНоса_Значение | получен',
#  'ЛабораторныеИсследования1_МазокИзЗеваИНоса_ЗначениеПредставление | получен',
#  'ЛабораторныеИсследования1_Кал_Значение | получен',
#  'ЛабораторныеИсследования1_Кал_ЗначениеПредставление | получен',
#  'ЛабораторныеИсследования1_RW_Значение | получен',
#  'ЛабораторныеИсследования1_RW_ЗначениеПредставление | получен',
#  'ЛабораторныеИсследования1_КровьНаЭнтеробиоз_Значение | получен',
#  'ЛабораторныеИсследования1_КровьНаЭнтеробиоз_ЗначениеПредставление | получен',
#  'Рентгенология1_ДокументПрием | nan',
#  'Рентгенология1_ДатаПриема | NaT',
#  'Рентгенология1_Салон | nan',
#  'Рентгенология1_СалонПредставление | nan',
#  'Рентгенология1_Специализация | nan',
#  'Рентгенология1_СпециализацияПредставление | nan',
#  'Рентгенология1_Легкие_Значение | nan',
#  'Рентгенология1_Легкие_ЗначениеПредставление | nan',
#  'Рентгенология1_Сердце_Значение | nan',
#  'Рентгенология1_Сердце_ЗначениеПредставление | nan',
#  'Рентгенология1_Заключение_Значение | nan',
#  'Рентгенология1_Заключение_ЗначениеПредставление | nan',
#  'Рентгенология2_ДокументПрием | nan',
#  'Рентгенология2_ДатаПриема | NaT',
#  'Рентгенология2_Салон | nan',
#  'Рентгенология2_СалонПредставление | nan',
#  'Рентгенология2_Специализация | nan',
#  'Рентгенология2_СпециализацияПредставление | nan',
#  'ПсихиатрияНаркология1_ДокументПрием | nan',
#  'ПсихиатрияНаркология1_ДатаПриема | NaT',
#  'ПсихиатрияНаркология1_Салон | nan',
#  'ПсихиатрияНаркология1_СалонПредставление | nan',
#  'ПсихиатрияНаркология1_Специализация | nan',
#  'ПсихиатрияНаркология1_СпециализацияПредставление | nan',
#  'ПсихиатрияНаркология1_ХР_Рекомендация1 | nan',
#  'ПсихиатрияНаркология1_ХР_Рекомендация1Представление | nan',
#  'ПсихиатрияНаркология1_ХР_Рекомендация2 | nan',
#  'ПсихиатрияНаркология1_ХР_РекомендацияСтр | nan',
#  'ПсихиатрияНаркология1_МКБ101 | nan',
#  'ПсихиатрияНаркология1_ДиагнозПредставление1 | nan',
#  'ПсихиатрияНаркология1_Детализация1 | nan',
#  'ПсихиатрияНаркология1_Классификация11 | nan',
#  'ПсихиатрияНаркология1_Классификация1Представление1 | nan',
#  'ПсихиатрияНаркология1_Классификация21 | nan',
#  'ПсихиатрияНаркология1_Классификация2Представление1 | nan',
#  'ПсихиатрияНаркология1_Классификация31 | nan',
#  'ПсихиатрияНаркология1_Классификация3Представление1 | nan',
#  'ПсихиатрияНаркология1_Противопоказание1 | nan',
#  'ПсихиатрияНаркология1_ПротивопоказаниеПредставление1 | nan',
#  'ПсихиатрияНаркология1_Профессиональное1 | nan',
#  'ПсихиатрияНаркология1_ПрофнепригодностьВременная1 | nan',
#  'ПсихиатрияНаркология1_ПрофнепригодностьВременнаяПредставление1 | nan',
#  'ПсихиатрияНаркология1_ДатаПриема_Значение | nan',
#  'ПсихиатрияНаркология1_ДатаПриема_ЗначениеПредставление | nan',
#  'ПсихиатрияНаркология1_Врач_Значение | nan',
#  'ПсихиатрияНаркология1_Врач_ЗначениеПредставление | nan',
#  'ПсихиатрияНаркология1_ГоденНегоден_Значение | nan',
#  'ПсихиатрияНаркология1_ГоденНегоден_ЗначениеПредставление | nan',
#  'ПсихиатрияНаркология1_Жалобы_Значение | nan',
#  'ПсихиатрияНаркология1_Жалобы_ЗначениеПредставление | nan',
#  'ПсихиатрияНаркология1_Анамнез_Значение | nan',
#  'ПсихиатрияНаркология1_Анамнез_ЗначениеПредставление | nan',
#  'ПсихиатрияНаркология1_УпотреблениеНаркотическихИПсихотропныхВеществ_Значение | nan',
#  'ПсихиатрияНаркология1_УпотреблениеНаркотическихИПсихотропныхВеществ_ЗначениеПредставление | nan',
#  'ПсихиатрияНаркология1_Чистая_Значение | nan',
#  'ПсихиатрияНаркология1_Чистая_ЗначениеПредставление | nan',
#  'ПсихиатрияНаркология1_БезСледовВВИнъекций_Значение | nan',
#  'ПсихиатрияНаркология1_БезСледовВВИнъекций_ЗначениеПредставление | nan',
#  'ПсихиатрияНаркология1_СоСледамиВВИнъекций_Значение | nan',
#  'ПсихиатрияНаркология1_СоСледамиВВИнъекций_ЗначениеПредставление | nan',
#  'ПсихиатрияНаркология1_OD_Значение | nan',
#  'ПсихиатрияНаркология1_OD_ЗначениеПредставление | nan',
#  'ПсихиатрияНаркология1_OS_Значение | nan',
#  'ПсихиатрияНаркология1_OS_ЗначениеПредставление | nan',
#  'ПсихиатрияНаркология1_РеакцияНаСвет_Значение | nan',
#  'ПсихиатрияНаркология1_РеакцияНаСвет_ЗначениеПредставление | nan',
#  'ПсихиатрияНаркология1_Контактен_Значение | nan',
#  'ПсихиатрияНаркология1_Контактен_ЗначениеПредставление | nan',
#  'ПсихиатрияНаркология1_НеКонтактен_Значение | nan',
#  'ПсихиатрияНаркология1_НеКонтактен_ЗначениеПредставление | nan',
#  'ПсихиатрияНаркология1_Адекватен_Значение | nan',
#  'ПсихиатрияНаркология1_Адекватен_ЗначениеПредставление | nan',
#  'ПсихиатрияНаркология1_НеАдекватен_Значение | nan',
#  'ПсихиатрияНаркология1_НеАдекватен_ЗначениеПредставление | nan',
#  'ПсихиатрияНаркология1_БредГаллюцинации_Значение | nan',
#  'ПсихиатрияНаркология1_БредГаллюцинации_ЗначениеПредставление | nan',
#  'ПсихиатрияНаркология1_Внимание_Значение | nan',
#  'ПсихиатрияНаркология1_Внимание_ЗначениеПредставление | nan',
#  'ПсихиатрияНаркология1_Память_Значение | nan',
#  'ПсихиатрияНаркология1_Память_ЗначениеПредставление | nan',
#  'ПсихиатрияНаркология1_ФонНастроения_Значение | nan',
#  'ПсихиатрияНаркология1_ФонНастроения_ЗначениеПредставление | nan',
#  'ПсихиатрияНаркология1_МышлениеВ_Значение | nan',
#  'ПсихиатрияНаркология1_МышлениеВ_ЗначениеПредставление | nan',
#  'ПсихиатрияНаркология1_Эмоционально_Значение | nan',
#  'ПсихиатрияНаркология1_Эмоционально_ЗначениеПредставление | nan',
#  'ПсихиатрияНаркология1_Двигательно_Значение | nan',
#  'ПсихиатрияНаркология1_Двигательно_ЗначениеПредставление | nan',
#  'ПсихиатрияНаркология1_УстановкаНаТрезвость_Значение | nan',
#  'ПсихиатрияНаркология1_УстановкаНаТрезвость_ЗначениеПредставление | nan',
#  'ПсихиатрияНаркология1_НаДУчетеСоСлов_Значение | nan',
#  'ПсихиатрияНаркология1_НаДУчетеСоСлов_ЗначениеПредставление | nan',
#  'ПсихиатрияНаркология1_ДанныхЗаПсихиатрическуюПатологиюНаМоментОсмотра_Значение | nan',
#  'ПсихиатрияНаркология1_ДанныхЗаПсихиатрическуюПатологиюНаМоментОсмотра_ЗначениеПредставление | nan',
#  'ПсихиатрияНаркология1_ВСобственнойЛичностиВремениМесте_Значение | nan',
#  'ПсихиатрияНаркология1_ВСобственнойЛичностиВремениМесте_ЗначениеПредставление | nan',
#  'ПсихиатрияНаркология1_Интеллект_Значение | nan',
#  'ПсихиатрияНаркология1_Интеллект_ЗначениеПредставление | nan',
#  'ПсихиатрияНаркология1_Диагноз_Значение | nan',
#  'ПсихиатрияНаркология1_Диагноз_ЗначениеПредставление | nan',
#  'Офтальмология1_ДокументПрием | 38c0c654-8ef0-11ec-80fe-0cc47aab8067',
#  'Офтальмология1_ДатаПриема | 2022-02-16 11:18:19',
#  'Офтальмология1_Салон | 1b071e3e-c87a-11e7-80de-708bcd7f83cd',
#  'Офтальмология1_СалонПредставление | МЦ№2',
#  'Офтальмология1_Специализация | 785d8a6e-5c72-11dd-8423-005056c00008',
#  'Офтальмология1_СпециализацияПредставление | Офтальмология',
#  'Офтальмология1_ХР_Рекомендация1 | nan',
#  'Офтальмология1_ХР_Рекомендация1Представление | nan',
#  'Офтальмология1_ХР_Рекомендация2 | nan',
#  'Офтальмология1_ХР_Рекомендация2Представление | nan',
#  'Офтальмология1_ХР_РекомендацияСтр | nan',
#  'Офтальмология1_МКБ101 | Z00.0',
#  'Офтальмология1_ДиагнозПредставление1 | Общий медицинский осмотр',
#  'Офтальмология1_Детализация1 | nan',
#  'Офтальмология1_Классификация11 | nan',
#  'Офтальмология1_Классификация1Представление1 | nan',
#  'Офтальмология1_Классификация21 | nan',
#  'Офтальмология1_Классификация2Представление1 | nan',
#  'Офтальмология1_Классификация31 | nan',
#  'Офтальмология1_Классификация3Представление1 | nan',
#  'Офтальмология1_Противопоказание1 | nan',
#  'Офтальмология1_Профессиональное1 | 0.0',
#  'Офтальмология1_ПрофнепригодностьВременная1 | БИТУФА_НеВыявлена',
#  'Офтальмология1_ПрофнепригодностьВременнаяПредставление1 | Годен',
#  'Офтальмология1_ДатаПриема_Значение | 16.02.2022',
#  'Офтальмология1_ДатаПриема_ЗначениеПредставление | 16.02.2022',
#  'Офтальмология1_Врач_Значение | Фахретдинова\xa0А.З.',
#  'Офтальмология1_Врач_ЗначениеПредставление | Фахретдинова\xa0А.З.',
#  'Офтальмология1_ГоденНегоден_Значение | 072d79e3-1cc0-11e8-80c9-0cc47aab8067',
#  'Офтальмология1_ГоденНегоден_ЗначениеПредставление | Годен',
#  'Офтальмология1_Жалобы_Значение | 1b66edfc-243b-11e8-80c9-0cc47aab8067',
#  'Офтальмология1_Жалобы_ЗначениеПредставление | не предъявляет',
#  'Офтальмология1_Анамнез_Значение | 3d58fa6c-243b-11e8-80c9-0cc47aab8067',
#  'Офтальмология1_Анамнез_ЗначениеПредставление | не отягощен',
#  'Офтальмология1_Цветовосприятие_Значение | 8b6cdf78-2440-11e8-80c9-0cc47aab8067',
#  'Офтальмология1_Цветовосприятие_ЗначениеПредставление | нормальный трихромат',
#  'Офтальмология1_OD_Значение | 1,0',
#  'Офтальмология1_OD_ЗначениеПредставление | 1,0',
#  'Офтальмология1_OS_Значение | 1,0',
#  'Офтальмология1_OS_ЗначениеПредставление | 1,0',
#  'Офтальмология1_Рефракция_Значение | bfdae751-2441-11e8-80c9-0cc47aab8067',
#  'Офтальмология1_Рефракция_ЗначениеПредставление | скиаскопическая',
#  'Офтальмология1_ДвигательныйАппаратГлаз_Значение | 68b3fc21-2442-11e8-80c9-0cc47aab8067',
#  'Офтальмология1_ДвигательныйАппаратГлаз_ЗначениеПредставление | без патологии',
#  'Офтальмология1_СлезныеПути_Значение | c03b27e7-2442-11e8-80c9-0cc47aab8067',
#  'Офтальмология1_СлезныеПути_ЗначениеПредставление | проходимы',
#  'Офтальмология1_Конъюнктива_Значение | f1c16938-2442-11e8-80c9-0cc47aab8067',
#  'Офтальмология1_Конъюнктива_ЗначениеПредставление | бледно – розовая',
#  'Офтальмология1_ПоложениеИПодвижностьГлазныхЯблок_Значение | 50971dd1-2443-11e8-80c9-0cc47aab8067',
#  'Офтальмология1_ПоложениеИПодвижностьГлазныхЯблок_ЗначениеПредставление | правильное',
#  'Офтальмология1_РеакцияЗрачковНаСвет_Значение | 90b6060d-2443-11e8-80c9-0cc47aab8067',
#  'Офтальмология1_РеакцияЗрачковНаСвет_ЗначениеПредставление | живая',
#  'Офтальмология1_ОптическиеСреды_Значение | c9a8cf6d-2443-11e8-80c9-0cc47aab8067',
#  'Офтальмология1_ОптическиеСреды_ЗначениеПредставление | прозрачные',
#  'Офтальмология1_ДискиЗрительныхНервовБледноРозовые_Значение | 0.0',
#  'Офтальмология1_ДискиЗрительныхНервовБледноРозовые_ЗначениеПредставление | Нет',
#  'Офтальмология1_ГраницыЧеткие_Значение | 0.0',
#  'Офтальмология1_ГраницыЧеткие_ЗначениеПредставление | Нет',
#  'Офтальмология1_Диагноз_Значение | [Z00.0] Общий медицинский осмотр_x000D_\n',
#  'Офтальмология1_Диагноз_ЗначениеПредставление | [Z00.0] Общий медицинский осмотр_x000D_\n',
#  'Оториноларингология1_ДокументПрием | f54ffc36-8eee-11ec-80fe-0cc47aab8067',
#  'Оториноларингология1_ДатаПриема | 2022-02-16 11:09:15',
#  'Оториноларингология1_Салон | 1b071e3e-c87a-11e7-80de-708bcd7f83cd',
#  'Оториноларингология1_СалонПредставление | МЦ№2',
#  'Оториноларингология1_Специализация | eebe3e98-233d-11e2-9496-1803736d59cd',
#  'Оториноларингология1_СпециализацияПредставление | Оториноларингология',
#  'Оториноларингология1_ХР_Рекомендация1 | nan',
#  'Оториноларингология1_ХР_Рекомендация1Представление | nan',
#  'Оториноларингология1_ХР_Рекомендация2 | nan',
#  'Оториноларингология1_МКБ101 | Z00.0',
#  'Оториноларингология1_ДиагнозПредставление1 | Общий медицинский осмотр',
#  'Оториноларингология1_Детализация1 | nan',
#  'Оториноларингология1_Классификация11 | nan',
#  'Оториноларингология1_Классификация1Представление1 | nan',
#  'Оториноларингология1_Профессиональное1 | 0.0',
#  'Оториноларингология1_ПрофнепригодностьВременная1 | БИТУФА_НеВыявлена',
#  'Оториноларингология1_ПрофнепригодностьВременнаяПредставление1 | Годен',
#  'Оториноларингология1_ДатаПриема_Значение | 16.02.2022',
#  'Оториноларингология1_ДатаПриема_ЗначениеПредставление | 16.02.2022',
#  'Оториноларингология1_Врач_Значение | Хафизова\xa0Э.С.',
#  'Оториноларингология1_Врач_ЗначениеПредставление | Хафизова\xa0Э.С.',
#  'Оториноларингология1_ГоденНегоден_Значение | 072d79e3-1cc0-11e8-80c9-0cc47aab8067',
#  'Оториноларингология1_ГоденНегоден_ЗначениеПредставление | Годен',
#  'Оториноларингология1_Жалобы_Значение | 1b66edfc-243b-11e8-80c9-0cc47aab8067',
#  'Оториноларингология1_Жалобы_ЗначениеПредставление | не предъявляет',
#  'Оториноларингология1_Анамнез_Значение | 3d58fa6c-243b-11e8-80c9-0cc47aab8067',
#  'Оториноларингология1_Анамнез_ЗначениеПредставление | не отягощен',
#  'Оториноларингология1_ДефектыРечи_Значение | 9d4927f2-243c-11e8-80c9-0cc47aab8067',
#  'Оториноларингология1_ДефектыРечи_ЗначениеПредставление | нет',
#  'Оториноларингология1_СлизистаяПолостиНоса_Значение | e205a37f-243c-11e8-80c9-0cc47aab8067',
#  'Оториноларингология1_СлизистаяПолостиНоса_ЗначениеПредставление | розовая',
#  'Оториноларингология1_НосоваяПерегородка_Значение | 585a777a-243d-11e8-80c9-0cc47aab8067',
#  'Оториноларингология1_НосоваяПерегородка_ЗначениеПредставление | по центру',
#  'Оториноларингология1_НосовоеДыхание_Значение | 81438d92-243d-11e8-80c9-0cc47aab8067',
#  'Оториноларингология1_НосовоеДыхание_ЗначениеПредставление | свободное',
#  'Оториноларингология1_ЗаДужками_Значение | 1.0',
#  'Оториноларингология1_ЗаДужками_ЗначениеПредставление | Да',
#  'Оториноларингология1_Отсутствуют_Значение | 0.0',
#  'Оториноларингология1_Отсутствуют_ЗначениеПредставление | Нет',
#  'Оториноларингология1_Увеличены_Значение | 0.0',
#  'Оториноларингология1_Увеличены_ЗначениеПредставление | Нет',
#  'Оториноларингология1_УвеличеныСПробками_Значение | 0.0',
#  'Оториноларингология1_УвеличеныСПробками_ЗначениеПредставление | Нет',
#  'Оториноларингология1_УвеличеныСЛакунарнымНалетом_Значение | 0.0',
#  'Оториноларингология1_УвеличеныСЛакунарнымНалетом_ЗначениеПредставление | Нет',
#  'Оториноларингология1_ВСлуховыхПроходах_Значение | 6642943d-243e-11e8-80c9-0cc47aab8067',
#  'Оториноларингология1_ВСлуховыхПроходах_ЗначениеПредставление | свободно',
#  'Оториноларингология1_D_Значение | 6',
#  'Оториноларингология1_D_ЗначениеПредставление | 6',
#  'Оториноларингология1_S_Значение | 6',
#  'Оториноларингология1_S_ЗначениеПредставление | 6',
#  'Оториноларингология1_БарабанныеПерепонки_Значение | 2c883421-243f-11e8-80c9-0cc47aab8067',
#  'Оториноларингология1_БарабанныеПерепонки_ЗначениеПредставление | серые',
#  'Оториноларингология1_ВестибулярныйАнализатор_Значение | норма',
#  'Оториноларингология1_ВестибулярныйАнализатор_ЗначениеПредставление | норма',
#  'Оториноларингология1_Аудиометрия_Значение | норма',
#  'Оториноларингология1_Аудиометрия_ЗначениеПредставление | норма',
#  'Оториноларингология1_Диагноз_Значение | [Z00.0] Общий медицинский осмотр_x000D_\n',
#  'Оториноларингология1_Диагноз_ЗначениеПредставление | [Z00.0] Общий медицинский осмотр_x000D_\n',
#  'ХирургНеИсп1_ДокументПрием | 1fe4a1ec-8ef0-11ec-80fe-0cc47aab8067',
#  'ХирургНеИсп1_ДатаПриема | 2022-02-16 11:17:38',
#  'ХирургНеИсп1_Салон | 1b071e3e-c87a-11e7-80de-708bcd7f83cd',
#  'ХирургНеИсп1_СалонПредставление | МЦ№2',
#  'ХирургНеИсп1_Специализация | 8eaa4208-061e-11e6-9730-14dae9a1eee1',
#  'ХирургНеИсп1_СпециализацияПредставление | Хирург(не исп)',
#  'ХирургНеИсп1_МКБ101 | Z00.0',
#  'ХирургНеИсп1_ДиагнозПредставление1 | Общий медицинский осмотр',
#  'ХирургНеИсп1_Профессиональное1 | 0.0',
#  'ХирургНеИсп1_ПрофнепригодностьВременная1 | БИТУФА_НеВыявлена',
#  'ХирургНеИсп1_ПрофнепригодностьВременнаяПредставление1 | Годен',
#  'ХирургНеИсп1_ДатаПриема_Значение | 16.02.2022',
#  'ХирургНеИсп1_ДатаПриема_ЗначениеПредставление | 16.02.2022',
#  'ХирургНеИсп1_Врач_Значение | Фазылова\xa0Л.А.',
#  'ХирургНеИсп1_Врач_ЗначениеПредставление | Фазылова\xa0Л.А.',
#  'ХирургНеИсп1_ГоденНегоден_Значение | 072d79e3-1cc0-11e8-80c9-0cc47aab8067',
#  'ХирургНеИсп1_ГоденНегоден_ЗначениеПредставление | Годен',
#  'ХирургНеИсп1_Жалобы_Значение | 1b66edfc-243b-11e8-80c9-0cc47aab8067',
#  'ХирургНеИсп1_Жалобы_ЗначениеПредставление | не предъявляет',
#  'ХирургНеИсп1_Анамнез_Значение | 3d58fa6c-243b-11e8-80c9-0cc47aab8067',
#  'ХирургНеИсп1_Анамнез_ЗначениеПредставление | не отягощен',
#  'ХирургНеИсп1_ПериферическиеЛимфоузлы_Значение | f97e2530-244c-11e8-80c9-0cc47aab8067',
#  'ХирургНеИсп1_ПериферическиеЛимфоузлы_ЗначениеПредставление | не увеличены',
#  'ХирургНеИсп1_Язык_Значение | 56e5c68f-244d-11e8-80c9-0cc47aab8067',
#  'ХирургНеИсп1_Язык_ЗначениеПредставление | влажный',
#  'ХирургНеИсп1_Язык2_Значение | 6d39ffe2-244d-11e8-80c9-0cc47aab8067',
#  'ХирургНеИсп1_Язык2_ЗначениеПредставление | чистый',
#  'ХирургНеИсп1_Мягкий_Значение | 0.0',
#  'ХирургНеИсп1_Мягкий_ЗначениеПредставление | Нет',
#  'ХирургНеИсп1_Напряженный_Значение | 0.0',
#  'ХирургНеИсп1_Напряженный_ЗначениеПредставление | Нет',
#  'ХирургНеИсп1_БезболезненныйПриПальпации_Значение | 0.0',
#  'ХирургНеИсп1_БезболезненныйПриПальпации_ЗначениеПредставление | Нет',
#  'ХирургНеИсп1_Болезненный_Значение | 0.0',
#  'ХирургНеИсп1_Болезненный_ЗначениеПредставление | Нет',
#  'ХирургНеИсп1_ПеритонеальныеЗнаки_Значение | 6bd979f5-244e-11e8-80c9-0cc47aab8067',
#  'ХирургНеИсп1_ПеритонеальныеЗнаки_ЗначениеПредставление | отрицательные',
#  'ХирургНеИсп1_ОтрицателенСОбеихСторон_Значение | 0.0',
#  'ХирургНеИсп1_ОтрицателенСОбеихСторон_ЗначениеПредставление | Нет',
#  'ХирургНеИсп1_ПоложителенD_Значение | 0.0',
#  'ХирургНеИсп1_ПоложителенD_ЗначениеПредставление | Нет',
#  'ХирургНеИсп1_ПоложителенS_Значение | 0.0',
#  'ХирургНеИсп1_ПоложителенS_ЗначениеПредставление | Нет',
#  'ХирургНеИсп1_Свободное_Значение | 0.0',
#  'ХирургНеИсп1_Свободное_ЗначениеПредставление | Нет',
#  'ХирургНеИсп1_Затруднено_Значение | 0.0',
#  'ХирургНеИсп1_Затруднено_ЗначениеПредставление | Нет',
#  'ХирургНеИсп1_Болезненно_Значение | 0.0',
#  'ХирургНеИсп1_Болезненно_ЗначениеПредставление | Нет',
#  'ХирургНеИсп1_Безболезненно_Значение | 0.0',
#  'ХирургНеИсп1_Безболезненно_ЗначениеПредставление | Нет',
#  'ХирургНеИсп1_Учащено_Значение | 0.0',
#  'ХирургНеИсп1_Учащено_ЗначениеПредставление | Нет',
#  'ХирургНеИсп1_НеУчащено_Значение | 0.0',
#  'ХирургНеИсп1_НеУчащено_ЗначениеПредставление | Нет',
#  'ХирургНеИсп1_АнусИПрямаяКишка_Значение | 4fb2fb6f-2451-11e8-80c9-0cc47aab8067',
#  'ХирургНеИсп1_АнусИПрямаяКишка_ЗначениеПредставление | без патологии',
#  'ХирургНеИсп1_ДвиженияВСуставах_Значение | 906d4ab9-2451-11e8-80c9-0cc47aab8067',
#  'ХирургНеИсп1_ДвиженияВСуставах_ЗначениеПредставление | в полном объеме',
#  'ХирургНеИсп1_Диагноз_Значение | [Z00.0] Общий медицинский осмотр_x000D_\n',
#  'ХирургНеИсп1_Диагноз_ЗначениеПредставление | [Z00.0] Общий медицинский осмотр_x000D_\n',
#  'Гинекология1_ДокументПрием | nan',
#  'Гинекология1_ДатаПриема | NaT',
#  'Гинекология1_Салон | nan',
#  'Гинекология1_СалонПредставление | nan',
#  'Гинекология1_Специализация | nan',
#  'Гинекология1_СпециализацияПредставление | nan',
#  'Гинекология1_ХР_Рекомендация1 | nan',
#  'Гинекология1_ХР_Рекомендация1Представление | nan',
#  'Гинекология1_ХР_Рекомендация2 | nan',
#  'Гинекология1_ХР_Рекомендация2Представление | nan',
#  'Гинекология1_ХР_РекомендацияСтр | nan',
#  'Гинекология1_МКБ101 | nan',
#  'Гинекология1_ДиагнозПредставление1 | nan',
#  'Гинекология1_Детализация1 | nan',
#  'Гинекология1_Профессиональное1 | nan',
#  'Гинекология1_ПрофнепригодностьВременная1 | nan',
#  'Гинекология1_ПрофнепригодностьВременнаяПредставление1 | nan',
#  'Гинекология1_ДатаПриема_Значение | nan',
#  'Гинекология1_ДатаПриема_ЗначениеПредставление | nan',
#  'Гинекология1_Врач_Значение | nan',
#  'Гинекология1_Врач_ЗначениеПредставление | nan',
#  'Гинекология1_ГоденНегоден_Значение | nan',
#  'Гинекология1_ГоденНегоден_ЗначениеПредставление | nan',
#  'Гинекология1_Жалобы_Значение | nan',
#  'Гинекология1_Жалобы_ЗначениеПредставление | nan',
#  'Гинекология1_Анамнез_Значение | nan',
#  'Гинекология1_Анамнез_ЗначениеПредставление | nan',
#  'Гинекология1_Регулярные_Значение | nan',
#  'Гинекология1_Регулярные_ЗначениеПредставление | nan',
#  'Гинекология1_Нерегулярные_Значение | nan',
#  'Гинекология1_Нерегулярные_ЗначениеПредставление | nan',
#  'Гинекология1_Обильные_Значение | nan',
#  'Гинекология1_Обильные_ЗначениеПредставление | nan',
#  'Гинекология1_Умеренные_Значение | nan',
#  'Гинекология1_Умеренные_ЗначениеПредставление | nan',
#  'Гинекология1_Скудные_Значение | nan',
#  'Гинекология1_Скудные_ЗначениеПредставление | nan',
#  'Гинекология1_Болезненны_Значение | nan',
#  'Гинекология1_Болезненны_ЗначениеПредставление | nan',
#  'Гинекология1_Безболезненны_Значение | nan',
#  'Гинекология1_Безболезненны_ЗначениеПредставление | nan',
#  'Гинекология1_ДлительностьЦикла_Значение | nan',
#  'Гинекология1_ДлительностьЦикла_ЗначениеПредставление | nan',
#  'Гинекология1_МолочныеЖелезы_Значение | nan',
#  'Гинекология1_МолочныеЖелезы_ЗначениеПредставление | nan',
#  'Гинекология1_ОволосениеПоТипу_Значение | nan',
#  'Гинекология1_ОволосениеПоТипу_ЗначениеПредставление | nan',
#  'Гинекология1_НаружныеПоловыеОрганыРазвиты_Значение | nan',
#  'Гинекология1_НаружныеПоловыеОрганыРазвиты_ЗначениеПредставление | nan',
#  'Гинекология1_Влагалище_Значение | nan',
#  'Гинекология1_Влагалище_ЗначениеПредставление | nan',
#  'Гинекология1_ВыделенияИзПоловыхПутей_Значение | nan',
#  'Гинекология1_ВыделенияИзПоловыхПутей_ЗначениеПредставление | nan',
#  'Гинекология1_Чистая_Значение | nan',
#  'Гинекология1_Чистая_ЗначениеПредставление | nan',
#  'Гинекология1_Плотная_Значение | nan',
#  'Гинекология1_Плотная_ЗначениеПредставление | nan',
#  'Гинекология1_Эрозирована_Значение | nan',
#  'Гинекология1_Эрозирована_ЗначениеПредставление | nan',
#  'Гинекология1_РубцовоИзменена_Значение | nan',
#  'Гинекология1_РубцовоИзменена_ЗначениеПредставление | nan',
#  'Гинекология1_ЗевШейкиМатки_Значение | nan',
#  'Гинекология1_ЗевШейкиМатки_ЗначениеПредставление | nan',
#  'Гинекология1_ФормаШейкиМатки_Значение | nan',
#  'Гинекология1_ФормаШейкиМатки_ЗначениеПредставление | nan',
#  'Гинекология1_D1_Значение | nan',
#  'Гинекология1_D1_ЗначениеПредставление | nan',
#  'Гинекология1_D2_Значение | nan',
#  'Гинекология1_D2_ЗначениеПредставление | nan',
#  'Гинекология1_S1_Значение | nan',
#  'Гинекология1_S1_ЗначениеПредставление | nan',
#  'Гинекология1_S2_Значение | nan',
#  'Гинекология1_S2_ЗначениеПредставление | nan',
#  'Гинекология1_Своды_Значение | nan',
#  'Гинекология1_Своды_ЗначениеПредставление | nan',
#  'Гинекология1_ЛимфатическиеУзлы1_Значение | nan',
#  'Гинекология1_ЛимфатическиеУзлы1_ЗначениеПредставление | nan',
#  'Гинекология1_ЛимфатическиеУзлы2_Значение | nan',
#  'Гинекология1_ЛимфатическиеУзлы2_ЗначениеПредставление | nan',
#  'Гинекология1_ЗаднепроходноеОтверстие_Значение | nan',
#  'Гинекология1_ЗаднепроходноеОтверстие_ЗначениеПредставление | nan',
#  'Гинекология1_Увеличена_Значение | nan',
#  'Гинекология1_Увеличена_ЗначениеПредставление | nan',
#  'Гинекология1_Неувеличена_Значение | nan',
#  'Гинекология1_Неувеличена_ЗначениеПредставление | nan',
#  'Гинекология1_Мягкая_Значение | nan',
#  'Гинекология1_Мягкая_ЗначениеПредставление | nan',
#  'Гинекология1_Подвижная_Значение | nan',
#  'Гинекология1_Подвижная_ЗначениеПредставление | nan',
#  'Гинекология1_Неподвижная_Значение | nan',
#  'Гинекология1_Неподвижная_ЗначениеПредставление | nan',
#  'Гинекология1_Болезненная_Значение | nan',
#  'Гинекология1_Болезненная_ЗначениеПредставление | nan',
#  'Гинекология1_Безболезненная_Значение | nan',
#  'Гинекология1_Безболезненная_ЗначениеПредставление | nan',
#  'Гинекология1_МазкиСданы_Значение | nan',
#  'Гинекология1_МазкиСданы_ЗначениеПредставление | nan',
#  'Гинекология1_Диагноз_Значение | nan',
#  'Гинекология1_Диагноз_ЗначениеПредставление | nan',
#  'ФункциональнаяДиагностика1_ДокументПрием | 1877cd94-8eef-11ec-80fe-0cc47aab8067',
#  'ФункциональнаяДиагностика1_ДатаПриема | 2022-02-16 11:10:12',
#  'ФункциональнаяДиагностика1_Салон | 1b071e3e-c87a-11e7-80de-708bcd7f83cd',
#  'ФункциональнаяДиагностика1_СалонПредставление | МЦ№2',
#  'ФункциональнаяДиагностика1_Специализация | 74e3ecc5-4180-11e8-80ca-0cc47aab8067',
#  'ФункциональнаяДиагностика1_СпециализацияПредставление | Функциональная диагностика',
#  'ФункциональнаяДиагностика1_ХР_Рекомендация1 | nan',
#  'ФункциональнаяДиагностика1_ХР_Рекомендация1Представление | nan',
#  'ФункциональнаяДиагностика1_ХР_Рекомендация2 | nan',
#  'ФункциональнаяДиагностика1_ОбследованиеПроведено_Значение | да',
#  'ФункциональнаяДиагностика1_ОбследованиеПроведено_ЗначениеПредставление | да',
#  'Стоматология1_ДокументПрием | e62522e8-8ef2-11ec-80fe-0cc47aab8067',
#  'Стоматология1_ДатаПриема | 2022-02-16 11:37:32',
#  'Стоматология1_Салон | 1b071e3e-c87a-11e7-80de-708bcd7f83cd',
#  'Стоматология1_СалонПредставление | МЦ№2',
#  'Стоматология1_Специализация | 46a057dd-aa58-11ea-80dd-0cc47aab8067',
#  'Стоматология1_СпециализацияПредставление | Стоматология',
#  'Стоматология1_ХР_Рекомендация1 | nan',
#  'Стоматология1_ХР_Рекомендация1Представление | nan',
#  'Стоматология1_ХР_Рекомендация2 | nan',
#  'Стоматология1_ХР_Рекомендация2Представление | nan',
#  'Стоматология1_МКБ101 | Z00.0',
#  'Стоматология1_ДиагнозПредставление1 | Общий медицинский осмотр',
#  'Стоматология1_Классификация11 | nan',
#  'Стоматология1_Классификация1Представление1 | nan',
#  'Стоматология1_Профессиональное1 | 0.0',
#  'Стоматология1_ПрофнепригодностьВременная1 | БИТУФА_НеВыявлена',
#  'Стоматология1_ПрофнепригодностьВременнаяПредставление1 | Годен',
#  'Стоматология1_ДатаПриема_Значение | 16.02.2022',
#  'Стоматология1_ДатаПриема_ЗначениеПредставление | 16.02.2022',
#  'Стоматология1_Врач_Значение | Хисамов\xa0Э.Э.',
#  'Стоматология1_Врач_ЗначениеПредставление | Хисамов\xa0Э.Э.',
#  'Стоматология1_ГоденНегоден_Значение | 072d79e3-1cc0-11e8-80c9-0cc47aab8067',
#  'Стоматология1_ГоденНегоден_ЗначениеПредставление | Годен',
#  'Стоматология1_Жалобы_Значение | 1b66edfc-243b-11e8-80c9-0cc47aab8067',
#  'Стоматология1_Жалобы_ЗначениеПредставление | не предъявляет',
#  'Стоматология1_Анамнез_Значение | 3d58fa6c-243b-11e8-80c9-0cc47aab8067',
#  'Стоматология1_Анамнез_ЗначениеПредставление | не отягощен',
#  'Стоматология1_Прикус_Значение | nan',
#  'Стоматология1_Прикус_ЗначениеПредставление | nan',
#  'Стоматология1_СлизистаяПолостиРта_Значение | розовая',
#  'Стоматология1_СлизистаяПолостиРта_ЗначениеПредставление | розовая',
#  'Стоматология1_Десны_Значение | 7625d83d-34a8-11e8-80c9-0cc47aab8067',
#  'Стоматология1_Десны_ЗначениеПредставление | без патологии',
#  'Стоматология1_Язык_Значение | a0b52ba5-34a8-11e8-80c9-0cc47aab8067',
#  'Стоматология1_Язык_ЗначениеПредставление | влажный',
#  'Стоматология1_ЯзыкСтрокой_Значение | чистый',
#  'Стоматология1_ЯзыкСтрокой_ЗначениеПредставление | чистый',
#  'Стоматология1_ПолостьРта_Значение | 1a934758-34a9-11e8-80c9-0cc47aab8067',
#  'Стоматология1_ПолостьРта_ЗначениеПредставление | санирована',
#  'Стоматология1_Диагноз_Значение | [Z00.0] Общий медицинский осмотр_x000D_\n',
#  'Стоматология1_Диагноз_ЗначениеПредставление | [Z00.0] Общий медицинский осмотр_x000D_\n',
#  'Эндоскопия1_ДокументПрием | 6819b34a-8eee-11ec-80fe-0cc47aab8067',
#  'Эндоскопия1_ДатаПриема | 2022-02-16 11:05:24',
#  'Эндоскопия1_Салон | 1b071e3e-c87a-11e7-80de-708bcd7f83cd',
#  'Эндоскопия1_СалонПредставление | МЦ№2',
#  'Эндоскопия1_Специализация | 9a212557-2465-11e8-80c9-0cc47aab8067',
#  'Эндоскопия1_СпециализацияПредставление | Эндоскопия',
#  'Эндоскопия1_ЖалобыДополнение_Значение | Патологии со стороны слизистой пищевода, желудка и 12 п.к. не выявлено. ',
#  'Эндоскопия1_ЖалобыДополнение_ЗначениеПредставление | Патологии со стороны слизистой пищевода, желудка и 12 п.к. не выявлено. ',
#  'Эндоскопия1_АллергическиеРеакции_Значение | Отрицает',
#  'Эндоскопия1_АллергическиеРеакции_ЗначениеПредставление | Отрицает',
#  'Терапия1_ДокументПрием | b604a3dd-8eff-11ec-80fe-0cc47aab8067',
#  'Терапия1_ДатаПриема | 2022-02-16 13:09:12',
#  'Терапия1_Салон | 1b071e3e-c87a-11e7-80de-708bcd7f83cd',
#  'Терапия1_СалонПредставление | МЦ№2',
#  'Терапия1_Специализация | 91d8a3f0-d7cf-11e1-bab2-1803736d59cd',
#  'Терапия1_СпециализацияПредставление | Терапия',
#  'Терапия1_ХР_Рекомендация1 | nan',
#  'Терапия1_ХР_Рекомендация1Представление | nan',
#  'Терапия1_ХР_Рекомендация2 | nan',
#  'Терапия1_ХР_Рекомендация2Представление | nan',
#  'Терапия1_ХР_РекомендацияСтр | nan',
#  'Терапия1_Температура_Значение | 36.6',
#  'Терапия1_Температура_ЗначениеПредставление | 36.6',
#  'Терапия1_АртериальноеДавление_Значение | 120\\80',
#  'Терапия1_АртериальноеДавление_ЗначениеПредставление | 120\\80',
#  'Терапия1_П_Значение | 80.0',
#  'Терапия1_П_ЗначениеПредставление | 80.0',
#  'Терапия1_ЧД_Значение | 18.0',
#  'Терапия1_ЧД_ЗначениеПредставление | 18.0',
#  'Терапия1_ДатаПриема_Значение | 16.02.2022',
#  'Терапия1_ДатаПриема_ЗначениеПредставление | 16.02.2022',
#  'Терапия1_АнамнезДополнение_Значение | nan',
#  'Терапия1_АнамнезДополнение_ЗначениеПредставление | nan',
#  'Терапия1_Миндалины_Значение | 82610b3c-1cbe-11e8-80c9-0cc47aab8067',
#  'Терапия1_Миндалины_ЗначениеПредставление | обычные',
#  'Терапия1_Врач_Значение | Черепанова\xa0Н.А.',
#  'Терапия1_Врач_ЗначениеПредставление | Черепанова\xa0Н.А.',
#  'Терапия1_ГоденНегоден_Значение | 072d79e3-1cc0-11e8-80c9-0cc47aab8067',
#  'Терапия1_ГоденНегоден_ЗначениеПредставление | Годен',
#  'Терапия1_Печень_Значение | 70e21f98-1cc1-11e8-80c9-0cc47aab8067',
#  'Терапия1_Печень_ЗначениеПредставление | не увеличена',
#  'Терапия1_Жалобы_Значение | 1b66edfc-243b-11e8-80c9-0cc47aab8067',
#  'Терапия1_Жалобы_ЗначениеПредставление | не предъявляет',
#  'Терапия1_Анамнез_Значение | 3d58fa6c-243b-11e8-80c9-0cc47aab8067',
#  'Терапия1_Анамнез_ЗначениеПредставление | не отягощен',
#  'Терапия1_ОбщееСостояние_Значение | 5a11f8d8-7dbe-11e8-80ce-0cc47aab8067',
#  'Терапия1_ОбщееСостояние_ЗначениеПредставление | удовлетворительное',
#  'Терапия1_ФизиологическойОкраскиИВлажности_Значение | 1.0',
#  'Терапия1_ФизиологическойОкраскиИВлажности_ЗначениеПредставление | Да',
#  'Терапия1_Гиперемированы_Значение | 0.0',
#  'Терапия1_Гиперемированы_ЗначениеПредставление | Нет',
#  'Терапия1_СВысыпаниями_Значение | false',
#  'Терапия1_СВысыпаниями_ЗначениеПредставление | Нет',
#  'Терапия1_ПовышеннойВлажности_Значение | 0.0',
#  'Терапия1_ПовышеннойВлажности_ЗначениеПредставление | Нет',
#  'Терапия1_Сухие_Значение | 0.0',
#  'Терапия1_Сухие_ЗначениеПредставление | Нет',
#  'Терапия1_Бледные_Значение | 0.0',
#  'Терапия1_Бледные_ЗначениеПредставление | Нет',
#  'Терапия1_Чистый_Значение | 1.0',
#  'Терапия1_Чистый_ЗначениеПредставление | Да',
#  'Терапия1_Влажный_Значение | 1.0',
#  'Терапия1_Влажный_ЗначениеПредставление | Да',
#  'Терапия1_ОбложенБелым_Значение | 0.0',
#  'Терапия1_ОбложенБелым_ЗначениеПредставление | Нет',
#  'Терапия1_ОбложенЖелтоватоБелымНалетом_Значение | 0.0',
#  'Терапия1_ОбложенЖелтоватоБелымНалетом_ЗначениеПредставление | Нет',
#  'Терапия1_ОбложенЖелтоватоЗеленымНалетом_Значение | 0.0',
#  'Терапия1_ОбложенЖелтоватоЗеленымНалетом_ЗначениеПредставление | Нет',
#  'Терапия1_Гиперемированный_Значение | 0.0',
#  'Терапия1_Гиперемированный_ЗначениеПредставление | Нет',
#  'Терапия1_Отечный_Значение | 0.0',
#  'Терапия1_Отечный_ЗначениеПредставление | Нет',
#  'Терапия1_Везикулярное_Значение | 1.0',
#  'Терапия1_Везикулярное_ЗначениеПредставление | Да',
#  'Терапия1_Жесткое_Значение | 0.0',
#  'Терапия1_Жесткое_ЗначениеПредставление | Нет',
#  'Терапия1_Ослабленное_Значение | 0.0',
#  'Терапия1_Ослабленное_ЗначениеПредставление | Нет',
#  'Терапия1_Нет_Значение | 1.0',
#  'Терапия1_Нет_ЗначениеПредставление | Да',
#  'Терапия1_Разнокалиберные_Значение | 0.0',
#  'Терапия1_Разнокалиберные_ЗначениеПредставление | Нет',
#  'Терапия1_Мелкопузырчатые_Значение | 0.0',
#  'Терапия1_Мелкопузырчатые_ЗначениеПредставление | Нет',
#  'Терапия1_Крупнопузырчатые_Значение | 0.0',
#  'Терапия1_Крупнопузырчатые_ЗначениеПредставление | Нет',
#  'Терапия1_Крепетирующие_Значение | 0.0',
#  'Терапия1_Крепетирующие_ЗначениеПредставление | Нет',
#  'Терапия1_Ритмичные_Значение | 1.0',
#  'Терапия1_Ритмичные_ЗначениеПредставление | Да',
#  'Терапия1_Аритмичные_Значение | 0.0',
#  'Терапия1_Аритмичные_ЗначениеПредставление | Нет',
#  'Терапия1_Ясные_Значение | 1.0',
#  'Терапия1_Ясные_ЗначениеПредставление | Да',
#  'Терапия1_Приглушенные_Значение | 0.0',
#  'Терапия1_Приглушенные_ЗначениеПредставление | Нет',
#  'Терапия1_Болезненный_Значение | 0.0',
#  'Терапия1_Болезненный_ЗначениеПредставление | Нет',
#  'Терапия1_Безболезненный_Значение | 1.0',
#  'Терапия1_Безболезненный_ЗначениеПредставление | Да',
#  'Терапия1_Стул_Значение | 9317ac64-7dd0-11e8-80ce-0cc47aab8067',
#  'Терапия1_Стул_ЗначениеПредставление | без особенностей',
#  'Терапия1_Диурез_Значение | bb13b7c8-7dd0-11e8-80ce-0cc47aab8067',
#  'Терапия1_Диурез_ЗначениеПредставление | без особенностей',
#  'Терапия1_Мягкий_Значение | 1.0',
#  'Терапия1_Мягкий_ЗначениеПредставление | Да',
#  'Дерматовенерология1_ДокументПрием | nan',
#  'Дерматовенерология1_ДатаПриема | NaT',
#  'Дерматовенерология1_Салон | nan',
#  'Дерматовенерология1_СалонПредставление | nan',
#  'Дерматовенерология1_Специализация | nan',
#  'Дерматовенерология1_СпециализацияПредставление | nan',
#  'Дерматовенерология1_ХР_Рекомендация1 | nan',
#  'Дерматовенерология1_ХР_Рекомендация1Представление | nan',
#  'Дерматовенерология1_ХР_Рекомендация2 | nan',
#  'Дерматовенерология1_ХР_Рекомендация2Представление | nan',
#  'Дерматовенерология1_ХР_РекомендацияСтр | nan',
#  'Дерматовенерология1_МКБ101 | nan',
#  'Дерматовенерология1_ДиагнозПредставление1 | nan',
#  'Дерматовенерология1_Детализация1 | nan',
#  'Дерматовенерология1_Классификация11 | nan',
#  'Дерматовенерология1_Классификация1Представление1 | nan',
#  'Дерматовенерология1_Классификация21 | nan',
#  'Дерматовенерология1_Классификация2Представление1 | nan',
#  'Дерматовенерология1_Профессиональное1 | nan',
#  'Дерматовенерология1_ПрофнепригодностьВременная1 | nan',
#  'Дерматовенерология1_ПрофнепригодностьВременнаяПредставление1 | nan',
#  'Дерматовенерология1_ДатаПриема_Значение | nan',
#  'Дерматовенерология1_ДатаПриема_ЗначениеПредставление | nan',
#  'Дерматовенерология1_Врач_Значение | nan',
#  'Дерматовенерология1_Врач_ЗначениеПредставление | nan',
#  'Дерматовенерология1_ГоденНегоден_Значение | nan',
#  'Дерматовенерология1_ГоденНегоден_ЗначениеПредставление | nan',
#  'Дерматовенерология1_Жалобы_Значение | nan',
#  'Дерматовенерология1_Жалобы_ЗначениеПредставление | nan',
#  'Дерматовенерология1_Анамнез_Значение | nan',
#  'Дерматовенерология1_Анамнез_ЗначениеПредставление | nan',
#  'Дерматовенерология1_КожныеПокровы_Значение | nan',
#  'Дерматовенерология1_КожныеПокровы_ЗначениеПредставление | nan',
#  'Дерматовенерология1_НогтевыеПластинки_Значение | nan',
#  'Дерматовенерология1_НогтевыеПластинки_ЗначениеПредставление | nan',
#  'Дерматовенерология1_КожаВолосистойЧастиГоловы_Значение | nan',
#  'Дерматовенерология1_КожаВолосистойЧастиГоловы_ЗначениеПредставление | nan',
#  'Дерматовенерология1_Диагноз_Значение | nan',
#  'Дерматовенерология1_Диагноз_ЗначениеПредставление | nan',
#  'Рентгенология1_МКБ101 | nan',
#  'Рентгенология1_ДиагнозПредставление1 | nan',
#  'Рентгенология1_Детализация1 | nan',
#  'Рентгенология1_Профессиональное1 | nan',
#  'Рентгенология1_ПрофнепригодностьВременная1 | nan',
#  'Рентгенология1_ПрофнепригодностьВременнаяПредставление1 | nan',
#  'Неврология1_ДокументПрием | 4ece6e1b-8eed-11ec-80fe-0cc47aab8067',
#  'Неврология1_ДатаПриема | 2022-02-16 10:57:23',
#  'Неврология1_Салон | 1b071e3e-c87a-11e7-80de-708bcd7f83cd',
#  'Неврология1_СалонПредставление | МЦ№2',
#  'Неврология1_Специализация | c099f7d1-aa57-11ea-80dd-0cc47aab8067',
#  'Неврология1_СпециализацияПредставление | Неврология',
#  'Неврология1_ХР_Рекомендация1 | nan',
#  'Неврология1_ХР_Рекомендация1Представление | nan',
#  'Неврология1_ХР_Рекомендация2 | nan',
#  'Неврология1_ХР_РекомендацияСтр | nan',
#  'Неврология1_МКБ101 | Z00.0',
#  'Неврология1_ДиагнозПредставление1 | Общий медицинский осмотр',
#  'Неврология1_Детализация1 | nan',
#  'Неврология1_Классификация11 | nan',
#  'Неврология1_Классификация1Представление1 | nan',
#  'Неврология1_Классификация21 | nan',
#  'Неврология1_Классификация2Представление1 | nan',
#  'Неврология1_Профессиональное1 | 0.0',
#  'Неврология1_ПрофнепригодностьВременная1 | БИТУФА_НеВыявлена',
#  'Неврология1_ПрофнепригодностьВременнаяПредставление1 | Годен',
#  'Неврология1_ДатаПриема_Значение | 16.02.2022',
#  'Неврология1_ДатаПриема_ЗначениеПредставление | 16.02.2022',
#  'Неврология1_Врач_Значение | Шубин\xa0А.А.',
#  'Неврология1_Врач_ЗначениеПредставление | Шубин\xa0А.А.',
#  'Неврология1_ГоденНегоден_Значение | 072d79e3-1cc0-11e8-80c9-0cc47aab8067',
#  'Неврология1_ГоденНегоден_ЗначениеПредставление | Годен',
#  'Неврология1_Жалобы_Значение | 1b66edfc-243b-11e8-80c9-0cc47aab8067',
#  'Неврология1_Жалобы_ЗначениеПредставление | не предъявляет',
#  'Неврология1_Анамнез_Значение | 3d58fa6c-243b-11e8-80c9-0cc47aab8067',
#  'Неврология1_Анамнез_ЗначениеПредставление | не отягощен',
#  'Неврология1_Фотореакция_Значение | f2581838-2444-11e8-80c9-0cc47aab8067',
#  'Неврология1_Фотореакция_ЗначениеПредставление | живая',
#  'Неврология1_ВПолномОбъеме_Значение | 0.0',
#  'Неврология1_ВПолномОбъеме_ЗначениеПредставление | Нет',
#  'Неврология1_ОграниченоВверх_Значение | 0.0',
#  'Неврология1_ОграниченоВверх_ЗначениеПредставление | Нет',
#  'Неврология1_ОграниченоВниз_Значение | 0.0',
#  'Неврология1_ОграниченоВниз_ЗначениеПредставление | Нет',
#  'Неврология1_ОграниченоВлево_Значение | 0.0',
#  'Неврология1_ОграниченоВлево_ЗначениеПредставление | Нет',
#  'Неврология1_ОграниченоВправо_Значение | 0.0',
#  'Неврология1_ОграниченоВправо_ЗначениеПредставление | Нет',
#  'Неврология1_Нет_Значение | 0.0',
#  'Неврология1_Нет_ЗначениеПредставление | Нет',
#  'Неврология1_Горизонтальный_Значение | 0.0',
#  'Неврология1_Горизонтальный_ЗначениеПредставление | Нет',
#  'Неврология1_Вертикальный_Значение | 0.0',
#  'Неврология1_Вертикальный_ЗначениеПредставление | Нет',
#  'Неврология1_Ротационный_Значение | 0.0',
#  'Неврология1_Ротационный_ЗначениеПредставление | Нет',
#  'Неврология1_КрупноРазмашистый_Значение | 0.0',
#  'Неврология1_КрупноРазмашистый_ЗначениеПредставление | Нет',
#  'Неврология1_СреднеРазмашистый_Значение | 0.0',
#  'Неврология1_СреднеРазмашистый_ЗначениеПредставление | Нет',
#  'Неврология1_МелкоРазмашистый_Значение | 0.0',
#  'Неврология1_МелкоРазмашистый_ЗначениеПредставление | Нет',
#  'Неврология1_ПостоянныйВКраевыхОтведениях_Значение | 0.0',
#  'Неврология1_ПостоянныйВКраевыхОтведениях_ЗначениеПредставление | Нет',
#  'Неврология1_Глотание_Значение | af10cbd3-2446-11e8-80c9-0cc47aab8067',
#  'Неврология1_Глотание_ЗначениеПредставление | нормальное',
#  'Неврология1_ТочкиВыхода5ПарыНервов_Значение | d60890b4-2446-11e8-80c9-0cc47aab8067',
#  'Неврология1_ТочкиВыхода5ПарыНервов_ЗначениеПредставление | безболезненны',
#  'Неврология1_Язык_Значение | f9745de3-2446-11e8-80c9-0cc47aab8067',
#  'Неврология1_Язык_ЗначениеПредставление | по средней линии',
#  'Неврология1_ВПозеРомберга_Значение | 20c54694-2447-11e8-80c9-0cc47aab8067',
#  'Неврология1_ВПозеРомберга_ЗначениеПредставление | устойчив',
#  'Неврология1_ПНП_Значение | 4015e345-2447-11e8-80c9-0cc47aab8067',
#  'Неврология1_ПНП_ЗначениеПредставление | удовлетворительная',
#  'Неврология1_МышечнаяСила_Значение | 5.0',
#  'Неврология1_МышечнаяСила_ЗначениеПредставление | 5.0',
#  'Неврология1_МышечныйТонус_Значение | 71b4ed7b-2447-11e8-80c9-0cc47aab8067',
#  'Неврология1_МышечныйТонус_ЗначениеПредставление | сохранен',
#  'Неврология1_D_Значение | 8af07fa4-244a-11e8-80c9-0cc47aab8067',
#  'Неврология1_D_ЗначениеПредставление | живые',
#  'Неврология1_S_Значение | a74d657a-244a-11e8-80c9-0cc47aab8067',
#  'Неврология1_S_ЗначениеПредставление | живые',
#  'Неврология1_Чувствительность_Значение | e853529c-244a-11e8-80c9-0cc47aab8067',
#  'Неврология1_Чувствительность_ЗначениеПредставление | сохранена',
#  'Неврология1_Дермографизм_Значение | 178f15af-244b-11e8-80c9-0cc47aab8067',
#  'Неврология1_Дермографизм_ЗначениеПредставление | выражен',
#  'Неврология1_ПатологическиеИМенингиальныеЗнаки_Значение | нет',
#  'Неврология1_ПатологическиеИМенингиальныеЗнаки_ЗначениеПредставление | нет',
#  'Неврология1_Диагноз_Значение | [Z00.0] Общий медицинский осмотр_x000D_\n',
#  'Неврология1_Диагноз_ЗначениеПредставление | [Z00.0] Общий медицинский осмотр_x000D_\n',
#  'Терапия1_МКБ101 | Z00.0',
#  'Терапия1_ДиагнозПредставление1 | Общий медицинский осмотр',
#  'Терапия1_Детализация1 | nan',
#  'Терапия1_Классификация11 | nan',
#  'Терапия1_Классификация1Представление1 | nan',
#  'Терапия1_Классификация21 | nan',
#  'Терапия1_Профессиональное1 | 0.0',
#  'Терапия1_ПрофнепригодностьВременная1 | БИТУФА_НеВыявлена',
#  'Терапия1_ПрофнепригодностьВременнаяПредставление1 | Годен',
#  'Терапия1_Рост_Значение | 180.0',
#  'Терапия1_Рост_ЗначениеПредставление | 180.0',
#  'Терапия1_Вес_Значение | 81',
#  'Терапия1_Вес_ЗначениеПредставление | 81.0',
#  'ПсихиатрияНаркология1_БезСледовСамопорезов_Значение | nan',
#  'ПсихиатрияНаркология1_БезСледовСамопорезов_ЗначениеПредставление | nan',
#  'Офтальмология1_АнамнезДополнение_Значение | nan',
#  'Офтальмология1_АнамнезДополнение_ЗначениеПредставление | nan',
#  'Офтальмология1_ODДополнение_Значение | nan',
#  'Офтальмология1_ODДополнение_ЗначениеПредставление | nan',
#  'Офтальмология1_OSДополнение_Значение | nan',
#  'Офтальмология1_OSДополнение_ЗначениеПредставление | nan',
#  'Дерматовенерология1_КожныеПокровыОкраска_Значение | nan',
#  'Дерматовенерология1_КожныеПокровыОкраска_ЗначениеПредставление | nan',
#  'Дерматовенерология1_КожныеПокровыВлажность_Значение | nan',
#  'Дерматовенерология1_КожныеПокровыВлажность_ЗначениеПредставление | nan',
#  'Дерматовенерология1_НаружныеПоловыеОрганы_Значение | nan',
#  'Дерматовенерология1_НаружныеПоловыеОрганы_ЗначениеПредставление | nan',
#  'Дерматовенерология1_ОбследованиеНаПедикулез_Значение | nan',
#  'Дерматовенерология1_ОбследованиеНаПедикулез_ЗначениеПредставление | nan',
#  'Терапия1_ЖалобыДополнение_Значение | nan',
#  'Терапия1_ЖалобыДополнение_ЗначениеПредставление | nan',
#  'УЗИДиагностика1_ДокументПрием | 998b4e29-8efb-11ec-80fe-0cc47aab8067',
#  'УЗИДиагностика1_ДатаПриема | 2022-02-16 12:39:47',
#  'УЗИДиагностика1_Салон | 1b071e3e-c87a-11e7-80de-708bcd7f83cd',
#  'УЗИДиагностика1_СалонПредставление | МЦ№2',
#  'УЗИДиагностика1_Специализация | 3252ceb7-fc4b-11e3-87f5-002618dcef2c',
#  'УЗИДиагностика1_СпециализацияПредставление | УЗИ-диагностика',
#  'УЗИДиагностика1_Заключение_Значение | Эхопатологии на момент осмотра не выявлено ',
#  'УЗИДиагностика1_Заключение_ЗначениеПредставление | Эхопатологии на момент осмотра не выявлено ',
#  'УЗИДиагностика1_Размеры_Значение | не увеличены',
#  'УЗИДиагностика1_Размеры_ЗначениеПредставление | не увеличены',
#  'УЗИДиагностика1_Контуры_Значение | ровные',
#  'УЗИДиагностика1_Контуры_ЗначениеПредставление | ровные',
#  'УЗИДиагностика1_ЭхогенностьПаренхимы_Значение | в норме',
#  'УЗИДиагностика1_ЭхогенностьПаренхимы_ЗначениеПредставление | в норме',
#  'УЗИДиагностика1_СтруктураПаренхимы_Значение | однородная',
#  'УЗИДиагностика1_СтруктураПаренхимы_ЗначениеПредставление | однородная',
#  'УЗИДиагностика1_СосудистыйРисунок_Значение | не изменен',
#  'УЗИДиагностика1_СосудистыйРисунок_ЗначениеПредставление | не изменен',
#  'УЗИДиагностика1_Холедох_Значение | 2',
#  'УЗИДиагностика1_Холедох_ЗначениеПредставление | 2',
#  'УЗИДиагностика1_Форма_Значение | правильная',
#  'УЗИДиагностика1_Форма_ЗначениеПредставление | правильная',
#  'УЗИДиагностика1_Стенки_Значение | 1,2',
#  'УЗИДиагностика1_Стенки_ЗначениеПредставление | 1,2',
#  'УЗИДиагностика1_ПеретяжкаПерегиб_Значение | не обнаружено',
#  'УЗИДиагностика1_ПеретяжкаПерегиб_ЗначениеПредставление | не обнаружено',
#  'УЗИДиагностика1_ВеныПортальнойСистемы_Значение | не расширены',
#  'УЗИДиагностика1_ВеныПортальнойСистемы_ЗначениеПредставление | не расширены',
#  'УЗИДиагностика1_Эхогенность_Значение | нормальная',
#  'УЗИДиагностика1_Эхогенность_ЗначениеПредставление | нормальная',
#  'УЗИДиагностика1_Структура_Значение | однородная',
#  'УЗИДиагностика1_Структура_ЗначениеПредставление | однородная',
#  'УЗИДиагностика1_Головка_Значение | 12.0',
#  'УЗИДиагностика1_Головка_ЗначениеПредставление | 12.0',
#  'УЗИДиагностика1_Тело_Значение | 9.0',
#  'УЗИДиагностика1_Тело_ЗначениеПредставление | 9.0',
#  'УЗИДиагностика1_Хвост_Значение | 16',
#  'УЗИДиагностика1_Хвост_ЗначениеПредставление | 16',
#  'УЗИДиагностика1_ВирсунговПроток_Значение | 1,1',
#  'УЗИДиагностика1_ВирсунговПроток_ЗначениеПредставление | 1,1',
#  'Хирургия1_ДокументПрием | nan',
#  'Хирургия1_ДатаПриема | NaT',
#  'Хирургия1_Салон | nan',
#  'Хирургия1_СалонПредставление | nan',
#  'Хирургия1_Специализация | nan',
#  'Хирургия1_СпециализацияПредставление | nan',
#  'Хирургия1_ХР_Рекомендация1 | nan',
#  'Хирургия1_ХР_Рекомендация1Представление | nan',
#  'Хирургия1_ХР_Рекомендация2 | nan',
#  'Хирургия1_МКБ101 | nan',
#  'Хирургия1_ДиагнозПредставление1 | nan',
#  'Хирургия1_Детализация1 | nan',
#  'Хирургия1_Классификация11 | nan',
#  'Хирургия1_Классификация1Представление1 | nan',
#  'Хирургия1_Профессиональное1 | nan',
#  'Хирургия1_ПрофнепригодностьВременная1 | nan',
#  'Хирургия1_ПрофнепригодностьВременнаяПредставление1 | nan',
#  'Хирургия1_ДатаПриема_Значение | nan',
#  'Хирургия1_ДатаПриема_ЗначениеПредставление | nan',
#  'Хирургия1_Врач_Значение | nan',
#  'Хирургия1_Врач_ЗначениеПредставление | nan',
#  'Хирургия1_ГоденНегоден_Значение | nan',
#  'Хирургия1_ГоденНегоден_ЗначениеПредставление | nan',
#  'Хирургия1_Жалобы_Значение | nan',
#  'Хирургия1_Жалобы_ЗначениеПредставление | nan',
#  'Хирургия1_Анамнез_Значение | nan',
#  'Хирургия1_Анамнез_ЗначениеПредставление | nan',
#  'Хирургия1_ПериферическиеЛимфоузлы_Значение | nan',
#  'Хирургия1_ПериферическиеЛимфоузлы_ЗначениеПредставление | nan',
#  'Хирургия1_Язык_Значение | nan',
#  'Хирургия1_Язык_ЗначениеПредставление | nan',
#  'Хирургия1_Язык2_Значение | nan',
#  'Хирургия1_Язык2_ЗначениеПредставление | nan',
#  'Хирургия1_Мягкий_Значение | nan',
#  'Хирургия1_Мягкий_ЗначениеПредставление | nan',
#  'Хирургия1_Напряженный_Значение | nan',
#  'Хирургия1_Напряженный_ЗначениеПредставление | nan',
#  'Хирургия1_БезболезненныйПриПальпации_Значение | nan',
#  'Хирургия1_БезболезненныйПриПальпации_ЗначениеПредставление | nan',
#  'Хирургия1_Болезненный_Значение | nan',
#  'Хирургия1_Болезненный_ЗначениеПредставление | nan',
#  'Хирургия1_ПеритонеальныеЗнаки_Значение | nan',
#  'Хирургия1_ПеритонеальныеЗнаки_ЗначениеПредставление | nan',
#  'Хирургия1_ОтрицателенСОбеихСторон_Значение | nan',
#  'Хирургия1_ОтрицателенСОбеихСторон_ЗначениеПредставление | nan',
#  'Хирургия1_ПоложителенD_Значение | nan',
#  'Хирургия1_ПоложителенD_ЗначениеПредставление | nan',
#  'Хирургия1_ПоложителенS_Значение | nan',
#  'Хирургия1_ПоложителенS_ЗначениеПредставление | nan',
#  'Хирургия1_Свободное_Значение | nan',
#  'Хирургия1_Свободное_ЗначениеПредставление | nan',
#  'Хирургия1_Затруднено_Значение | nan',
#  'Хирургия1_Затруднено_ЗначениеПредставление | nan',
#  'Хирургия1_Болезненно_Значение | nan',
#  'Хирургия1_Болезненно_ЗначениеПредставление | nan',
#  'Хирургия1_Безболезненно_Значение | nan',
#  'Хирургия1_Безболезненно_ЗначениеПредставление | nan',
#  'Хирургия1_Учащено_Значение | nan',
#  'Хирургия1_Учащено_ЗначениеПредставление | nan',
#  'Хирургия1_НеУчащено_Значение | nan',
#  'Хирургия1_НеУчащено_ЗначениеПредставление | nan',
#  'Хирургия1_АнусИПрямаяКишка_Значение | nan',
#  'Хирургия1_АнусИПрямаяКишка_ЗначениеПредставление | nan',
#  'Хирургия1_ДвиженияВСуставах_Значение | nan',
#  'Хирургия1_ДвиженияВСуставах_ЗначениеПредставление | nan',
#  'УЗИДиагностика1_Содержимое_Значение | nan',
#  'УЗИДиагностика1_Содержимое_ЗначениеПредставление | nan',
#  'Хирургия1_Диагноз_Значение | nan',
#  'Хирургия1_Диагноз_ЗначениеПредставление | nan',
#  'Хирургия2_ДокументПрием | nan',
#  'Хирургия2_ДатаПриема | NaT',
#  'Хирургия2_Салон | nan',
#  'Хирургия2_СалонПредставление | nan',
#  'Хирургия2_Специализация | nan',
#  'Хирургия2_СпециализацияПредставление | nan',
#  'Хирургия2_ДатаПриема_Значение | nan',
#  'Хирургия2_ДатаПриема_ЗначениеПредставление | nan',
#  'Хирургия2_Врач_Значение | nan',
#  'Хирургия2_Врач_ЗначениеПредставление | nan',
#  'Хирургия2_ГоденНегоден_Значение | nan',
#  'Хирургия2_ГоденНегоден_ЗначениеПредставление | nan',
#  'Хирургия2_Жалобы_Значение | nan',
#  'Хирургия2_Жалобы_ЗначениеПредставление | nan',
#  'Хирургия2_Анамнез_Значение | nan',
#  'Хирургия2_Анамнез_ЗначениеПредставление | nan',
#  'Хирургия2_ПериферическиеЛимфоузлы_Значение | nan',
#  'Хирургия2_ПериферическиеЛимфоузлы_ЗначениеПредставление | nan',
#  'Хирургия2_Язык_Значение | nan',
#  'Хирургия2_Язык_ЗначениеПредставление | nan',
#  'Хирургия2_Язык2_Значение | nan',
#  'Хирургия2_Язык2_ЗначениеПредставление | nan',
#  'Хирургия2_Мягкий_Значение | nan',
#  'Хирургия2_Мягкий_ЗначениеПредставление | nan',
#  'Хирургия2_Напряженный_Значение | nan',
#  'Хирургия2_Напряженный_ЗначениеПредставление | nan',
#  'Хирургия2_БезболезненныйПриПальпации_Значение | nan',
#  'Хирургия2_БезболезненныйПриПальпации_ЗначениеПредставление | nan',
#  'Хирургия2_Болезненный_Значение | nan',
#  'Хирургия2_Болезненный_ЗначениеПредставление | nan',
#  'Хирургия2_ПеритонеальныеЗнаки_Значение | nan',
#  'Хирургия2_ПеритонеальныеЗнаки_ЗначениеПредставление | nan',
#  'Хирургия2_ОтрицателенСОбеихСторон_Значение | nan',
#  'Хирургия2_ОтрицателенСОбеихСторон_ЗначениеПредставление | nan',
#  'Хирургия2_ПоложителенD_Значение | nan',
#  'Хирургия2_ПоложителенD_ЗначениеПредставление | nan',
#  'Хирургия2_ПоложителенS_Значение | nan',
#  'Хирургия2_ПоложителенS_ЗначениеПредставление | nan',
#  'Хирургия2_Свободное_Значение | nan',
#  'Хирургия2_Свободное_ЗначениеПредставление | nan',
#  'Хирургия2_Затруднено_Значение | nan',
#  'Хирургия2_Затруднено_ЗначениеПредставление | nan',
#  'Хирургия2_Болезненно_Значение | nan',
#  'Хирургия2_Болезненно_ЗначениеПредставление | nan',
#  'Хирургия2_Безболезненно_Значение | nan',
#  'Хирургия2_Безболезненно_ЗначениеПредставление | nan',
#  'Хирургия2_Учащено_Значение | nan',
#  'Хирургия2_Учащено_ЗначениеПредставление | nan',
#  'Хирургия2_НеУчащено_Значение | nan',
#  'Хирургия2_НеУчащено_ЗначениеПредставление | nan',
#  'Хирургия2_АнусИПрямаяКишка_Значение | nan',
#  'Хирургия2_АнусИПрямаяКишка_ЗначениеПредставление | nan',
#  'Хирургия2_ДвиженияВСуставах_Значение | nan',
#  'Хирургия2_ДвиженияВСуставах_ЗначениеПредставление | nan',
#  'Офтальмология1_МКБ102 | nan',
#  'Офтальмология1_ДиагнозПредставление2 | nan',
#  'Офтальмология1_Детализация2 | nan',
#  'Офтальмология1_Классификация12 | nan',
#  'Офтальмология1_Классификация1Представление2 | nan',
#  'Офтальмология1_Классификация22 | nan',
#  'Офтальмология1_Классификация2Представление2 | nan',
#  'Офтальмология1_Классификация32 | nan',
#  'Офтальмология1_Классификация3Представление2 | nan',
#  'Офтальмология1_Профессиональное2 | nan',
#  'Офтальмология1_ПрофнепригодностьВременная2 | nan',
#  'Офтальмология1_ПрофнепригодностьВременнаяПредставление2 | nan',
#  'Терапия2_ДокументПрием | nan',
#  'Терапия2_ДатаПриема | NaT',
#  'Терапия2_Салон | nan',
#  'Терапия2_СалонПредставление | nan',
#  'Терапия2_Специализация | nan',
#  'Терапия2_СпециализацияПредставление | nan',
#  'Терапия2_ХР_Рекомендация1 | nan',
#  'Терапия2_ХР_Рекомендация1Представление | nan',
#  'Терапия2_ХР_Рекомендация2 | nan',
#  'Терапия2_ХР_Рекомендация2Представление | nan',
#  'Терапия2_МКБ101 | nan',
#  'Терапия2_ДиагнозПредставление1 | nan',
#  'Терапия2_Детализация1 | nan',
#  'Терапия2_Классификация11 | nan',
#  'Терапия2_Классификация1Представление1 | nan',
#  'Терапия2_Профессиональное1 | nan',
#  'Терапия2_ПрофнепригодностьВременная1 | nan',
#  'Терапия2_ПрофнепригодностьВременнаяПредставление1 | nan',
#  'Терапия2_Температура_Значение | nan',
#  'Терапия2_Температура_ЗначениеПредставление | nan',
#  'Терапия2_АртериальноеДавление_Значение | nan',
#  'Терапия2_АртериальноеДавление_ЗначениеПредставление | nan',
#  'Терапия2_П_Значение | nan',
#  'Терапия2_П_ЗначениеПредставление | nan',
#  'Терапия2_ЧД_Значение | nan',
#  'Терапия2_ЧД_ЗначениеПредставление | nan',
#  'Терапия2_Рост_Значение | nan',
#  'Терапия2_Рост_ЗначениеПредставление | nan',
#  'Терапия2_Вес_Значение | nan',
#  'Терапия2_Вес_ЗначениеПредставление | nan',
#  'Терапия2_ДатаПриема_Значение | nan',
#  'Терапия2_ДатаПриема_ЗначениеПредставление | nan',
#  'Терапия2_Миндалины_Значение | nan',
#  'Терапия2_Миндалины_ЗначениеПредставление | nan',
#  'Терапия2_Врач_Значение | nan',
#  'Терапия2_Врач_ЗначениеПредставление | nan',
#  'Терапия2_ГоденНегоден_Значение | nan',
#  'Терапия2_ГоденНегоден_ЗначениеПредставление | nan',
#  'Терапия2_Печень_Значение | nan',
#  'Терапия2_Печень_ЗначениеПредставление | nan',
#  'Терапия2_Жалобы_Значение | nan',
#  'Терапия2_Жалобы_ЗначениеПредставление | nan',
#  'Терапия2_Анамнез_Значение | nan',
#  'Терапия2_Анамнез_ЗначениеПредставление | nan',
#  'Терапия2_ОбщееСостояние_Значение | nan',
#  'Терапия2_ОбщееСостояние_ЗначениеПредставление | nan',
#  'Терапия2_ФизиологическойОкраскиИВлажности_Значение | nan',
#  'Терапия2_ФизиологическойОкраскиИВлажности_ЗначениеПредставление | nan',
#  'Терапия2_Гиперемированы_Значение | nan',
#  'Терапия2_Гиперемированы_ЗначениеПредставление | nan',
#  'Терапия2_СВысыпаниями_Значение | nan',
#  'Терапия2_СВысыпаниями_ЗначениеПредставление | nan',
#  'Терапия2_ПовышеннойВлажности_Значение | nan',
#  'Терапия2_ПовышеннойВлажности_ЗначениеПредставление | nan',
#  'Терапия2_Сухие_Значение | nan',
#  'Терапия2_Сухие_ЗначениеПредставление | nan',
#  'Терапия2_Бледные_Значение | nan',
#  'Терапия2_Бледные_ЗначениеПредставление | nan',
#  'Терапия2_Чистый_Значение | nan',
#  'Терапия2_Чистый_ЗначениеПредставление | nan',
#  'Терапия2_Влажный_Значение | nan',
#  'Терапия2_Влажный_ЗначениеПредставление | nan',
#  'Терапия2_ОбложенБелым_Значение | nan',
#  'Терапия2_ОбложенБелым_ЗначениеПредставление | nan',
#  'Терапия2_ОбложенЖелтоватоБелымНалетом_Значение | nan',
#  'Терапия2_ОбложенЖелтоватоБелымНалетом_ЗначениеПредставление | nan',
#  'Терапия2_ОбложенЖелтоватоЗеленымНалетом_Значение | nan',
#  'Терапия2_ОбложенЖелтоватоЗеленымНалетом_ЗначениеПредставление | nan',
#  'Терапия2_Гиперемированный_Значение | nan',
#  'Терапия2_Гиперемированный_ЗначениеПредставление | nan',
#  'Терапия2_Отечный_Значение | nan',
#  'Терапия2_Отечный_ЗначениеПредставление | nan',
#  'Терапия2_Везикулярное_Значение | nan',
#  'Терапия2_Везикулярное_ЗначениеПредставление | nan',
#  'Терапия2_Жесткое_Значение | nan',
#  'Терапия2_Жесткое_ЗначениеПредставление | nan',
#  'Терапия2_Ослабленное_Значение | nan',
#  'Терапия2_Ослабленное_ЗначениеПредставление | nan',
#  'Терапия2_Нет_Значение | nan',
#  'Терапия2_Нет_ЗначениеПредставление | nan',
#  'Терапия2_Разнокалиберные_Значение | nan',
#  'Терапия2_Разнокалиберные_ЗначениеПредставление | nan',
#  'Терапия2_Мелкопузырчатые_Значение | nan',
#  'Терапия2_Мелкопузырчатые_ЗначениеПредставление | nan',
#  'Терапия2_Крупнопузырчатые_Значение | nan',
#  'Терапия2_Крупнопузырчатые_ЗначениеПредставление | nan',
#  ...]

# %%
# Определяем колонки с типом данных str (строки) и содержащие значения в формате UUID
uuid_columns = df.select_dtypes(include='object').apply(lambda x: x.astype(str).str.contains(r'[a-f\d]{8}-[a-f\d]{4}-[a-f\d]{4}-[a-f\d]{4}-[a-f\d]{12}', regex=True)).any()

# Выводим названия колонок, содержащих UUID
uuid_columns = uuid_columns[uuid_columns == True].index
print("Колонки с UUID:")
print(uuid_columns.shape)
# Out:
# Колонки с UUID:
# (205,)
